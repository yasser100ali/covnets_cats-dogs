# %%
import os
import shutil
import pathlib
from tensorflow.keras.utils import image_dataset_from_directory

# Original directories
original_train_dir = pathlib.Path("/Users/yasserali/Documents/coding/github_projects/cats&dogs/train")
original_test_dir = pathlib.Path("/Users/yasserali/Documents/coding/github_projects/cats&dogs/test1")

# New base directory for smaller datasets
new_base_dir = pathlib.Path("cats_vs_dogs_small")

# Function to create subsets
def make_subset(subset_name, start_index, end_index, original_dir):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir, exist_ok=True)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            src = original_dir / fname
            dst = dir / fname
            if src.exists():
                shutil.copyfile(src, dst)
            else:
                print(f"File {src} does not exist")

# Create subsets
make_subset("train", start_index=0, end_index=1000, original_dir=original_train_dir)
make_subset("validation", start_index=1000, end_index=1500, original_dir=original_train_dir)
make_subset("test", start_index=1500, end_index=2500, original_dir=original_train_dir)  # Adjust to fit your structure

# Load datasets
train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)

validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)

test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# 2024-07-22 15:36:14.299179: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-07-22 15:36:14.299200: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-07-22 15:36:14.299207: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-07-22 15:36:14.299243: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-07-22 15:36:14.299255: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout

model = Sequential([
    Conv2D(16, (3, 3), activation = 'relu', input_shape = (180, 180, 3)),
    MaxPooling2D((2, 2,)),
    Dropout(0.3),
    
    Conv2D(32, (3, 3), activation = 'relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    
    Conv2D(64, (3, 3), activation = 'relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    
    Conv2D(32, (3, 3), activation = 'relu'),
    MaxPooling2D((2, 2)),
    
    Flatten(),
    
    Dense(512, activation = 'relu'),
    Dropout(0.4),
    
    Dense(1, activation = 'sigmoid')
])
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_23 (Conv2D)              │ (None, 178, 178, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 89, 89, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 89, 89, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 87, 87, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 43, 43, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 43, 43, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 41, 41, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (None, 20, 20, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 20, 20, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 18, 18, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 9, 9, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 2592)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 512)            │     1,327,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,370,177 (5.23 MB)
#  Trainable params: 1,370,177 (5.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras import optimizers 

model.compile(optimizer = optimizers.RMSprop(learning_rate = 1e-4),
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Define callbacks
checkpoint = ModelCheckpoint('best_model.keras',
                             monitor='val_loss',
                             save_best_only=True,
                             mode='min',
                             verbose=1)

early_stopping = EarlyStopping(patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=30,
    callbacks=[checkpoint, early_stopping]
)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_dataset)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4872 - loss: 18.3658
# Epoch 1: val_loss improved from inf to 0.77702, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.4874 - loss: 18.2568 - val_accuracy: 0.5000 - val_loss: 0.7770
# Epoch 2/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5087 - loss: 3.8833
# Epoch 2: val_loss improved from 0.77702 to 0.69274, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.5087 - loss: 3.8611 - val_accuracy: 0.5270 - val_loss: 0.6927
# Epoch 3/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5251 - loss: 1.6049
# Epoch 3: val_loss did not improve from 0.69274
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.5247 - loss: 1.5991 - val_accuracy: 0.5110 - val_loss: 0.6930
# Epoch 4/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4994 - loss: 0.9959
# Epoch 4: val_loss improved from 0.69274 to 0.69073, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.4994 - loss: 0.9936 - val_accuracy: 0.5090 - val_loss: 0.6907
# Epoch 5/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5167 - loss: 0.7673
# Epoch 5: val_loss improved from 0.69073 to 0.69060, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.5173 - loss: 0.7667 - val_accuracy: 0.5260 - val_loss: 0.6906
# Epoch 6/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5304 - loss: 0.7325
# Epoch 6: val_loss improved from 0.69060 to 0.68199, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.5304 - loss: 0.7322 - val_accuracy: 0.5260 - val_loss: 0.6820
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5245 - loss: 0.7049
# Epoch 7: val_loss improved from 0.68199 to 0.68075, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.5245 - loss: 0.7048 - val_accuracy: 0.5320 - val_loss: 0.6807
# Epoch 8/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5495 - loss: 0.6827
# Epoch 8: val_loss improved from 0.68075 to 0.67829, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.5492 - loss: 0.6826 - val_accuracy: 0.5310 - val_loss: 0.6783
# Epoch 9/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5345 - loss: 0.6871
# Epoch 9: val_loss improved from 0.67829 to 0.67513, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.5349 - loss: 0.6867 - val_accuracy: 0.5420 - val_loss: 0.6751
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5570 - loss: 0.6778
# Epoch 10: val_loss improved from 0.67513 to 0.67388, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5569 - loss: 0.6777 - val_accuracy: 0.5380 - val_loss: 0.6739
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5445 - loss: 0.6694
# Epoch 11: val_loss improved from 0.67388 to 0.67310, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5446 - loss: 0.6694 - val_accuracy: 0.5450 - val_loss: 0.6731
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5781 - loss: 0.6730
# Epoch 12: val_loss did not improve from 0.67310
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.5779 - loss: 0.6729 - val_accuracy: 0.5520 - val_loss: 0.6743
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5586 - loss: 0.6759
# Epoch 13: val_loss did not improve from 0.67310
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.5587 - loss: 0.6757 - val_accuracy: 0.5570 - val_loss: 0.6770
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5747 - loss: 0.6678
# Epoch 14: val_loss did not improve from 0.67310
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.5748 - loss: 0.6676 - val_accuracy: 0.5530 - val_loss: 0.6736
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5757 - loss: 0.6585
# Epoch 15: val_loss did not improve from 0.67310
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.5758 - loss: 0.6584 - val_accuracy: 0.5510 - val_loss: 0.6758
# Epoch 16/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5694 - loss: 0.6652
# Epoch 16: val_loss did not improve from 0.67310
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.5696 - loss: 0.6649 - val_accuracy: 0.5490 - val_loss: 0.6754
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5980 - loss: 0.6638
# Epoch 17: val_loss did not improve from 0.67310
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5978 - loss: 0.6637 - val_accuracy: 0.5570 - val_loss: 0.6756
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5560 - loss: 0.6721
# Epoch 18: val_loss did not improve from 0.67310
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.5561 - loss: 0.6719 - val_accuracy: 0.5600 - val_loss: 0.6758
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5780 - loss: 0.6677
# Epoch 19: val_loss did not improve from 0.67310
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.5783 - loss: 0.6675 - val_accuracy: 0.5660 - val_loss: 0.6750
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5705 - loss: 0.6548
# Epoch 20: val_loss improved from 0.67310 to 0.67118, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.5706 - loss: 0.6547 - val_accuracy: 0.5640 - val_loss: 0.6712
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5983 - loss: 0.6525
# Epoch 21: val_loss improved from 0.67118 to 0.66140, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5982 - loss: 0.6523 - val_accuracy: 0.5600 - val_loss: 0.6614
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6018 - loss: 0.6529
# Epoch 22: val_loss did not improve from 0.66140
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.6017 - loss: 0.6527 - val_accuracy: 0.5740 - val_loss: 0.6655
# Epoch 23/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5892 - loss: 0.6496
# Epoch 23: val_loss improved from 0.66140 to 0.66065, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.5897 - loss: 0.6491 - val_accuracy: 0.5640 - val_loss: 0.6607
# Epoch 24/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6146 - loss: 0.6435
# Epoch 24: val_loss improved from 0.66065 to 0.66054, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.6147 - loss: 0.6431 - val_accuracy: 0.5720 - val_loss: 0.6605
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6144 - loss: 0.6415
# Epoch 25: val_loss did not improve from 0.66054
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.6144 - loss: 0.6413 - val_accuracy: 0.5660 - val_loss: 0.6642
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6129 - loss: 0.6358
# Epoch 26: val_loss did not improve from 0.66054
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.6128 - loss: 0.6357 - val_accuracy: 0.5650 - val_loss: 0.6642
# Epoch 27/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6211 - loss: 0.6322
# Epoch 27: val_loss did not improve from 0.66054
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.6209 - loss: 0.6320 - val_accuracy: 0.5720 - val_loss: 0.6641
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6213 - loss: 0.6152
# Epoch 28: val_loss improved from 0.66054 to 0.66050, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.6212 - loss: 0.6152 - val_accuracy: 0.5690 - val_loss: 0.6605
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6311 - loss: 0.6218
# Epoch 29: val_loss improved from 0.66050 to 0.65916, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.6312 - loss: 0.6217 - val_accuracy: 0.5670 - val_loss: 0.6592
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6280 - loss: 0.6274
# Epoch 30: val_loss did not improve from 0.65916
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.6280 - loss: 0.6273 - val_accuracy: 0.5720 - val_loss: 0.6633
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5739 - loss: 0.6636
# Test accuracy: 0.5695000290870667

# %%
from keras.models import Sequential
from keras import layers
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation,GlobalMaxPooling2D
from keras import applications
from keras.utils import image_dataset_from_directory
from keras import optimizers
from keras.applications import VGG16
from keras.models import Model

image_size = 180
input_shape = (image_size, image_size, 3)

epochs = 5
batch_size = 16

pre_trained_model = VGG16(input_shape=input_shape, include_top=False, weights="imagenet")
    
for layer in pre_trained_model.layers[:15]:
    layer.trainable = False

for layer in pre_trained_model.layers[15:]:
    layer.trainable = True
    
last_layer = pre_trained_model.get_layer('block5_pool')
last_output = last_layer.output
    
# Flatten the output layer to 1 dimension
x = GlobalMaxPooling2D()(last_output)
# Add a fully connected layer with 512 hidden units and ReLU activation
x = Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
x = Dropout(0.5)(x)
# Add a final sigmoid layer for classification
x = layers.Dense(1, activation='sigmoid')(x)

model = Model(pre_trained_model.input, x)

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.SGD(learning_rate =1e-4, momentum=0.9),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 180, 180, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 180, 180, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 90, 90, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 90, 90, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 90, 90, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 45, 45, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 45, 45, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 22, 22, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 22, 22, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 11, 11, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 5, 5, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d_2          │ (None, 512)            │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_24 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,977,857 (57.14 MB)
#  Trainable params: 7,342,593 (28.01 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)

# %%
# Train the model
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=15,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.7919 - loss: 5.4942
# Epoch 1: val_loss improved from 0.65916 to 0.24787, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 620ms/step - accuracy: 0.7925 - loss: 5.4468 - val_accuracy: 0.9160 - val_loss: 0.2479
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9115 - loss: 0.2808
# Epoch 2: val_loss improved from 0.24787 to 0.20947, saving model to best_model.keras
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 611ms/step - accuracy: 0.9114 - loss: 0.2806 - val_accuracy: 0.9100 - val_loss: 0.2095
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.9282 - loss: 0.2035
# Epoch 3: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 619ms/step - accuracy: 0.9283 - loss: 0.2033 - val_accuracy: 0.9270 - val_loss: 0.2277
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9370 - loss: 0.1796
# Epoch 4: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 665ms/step - accuracy: 0.9371 - loss: 0.1790 - val_accuracy: 0.9270 - val_loss: 0.2362
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9634 - loss: 0.0967
# Epoch 5: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 664ms/step - accuracy: 0.9635 - loss: 0.0965 - val_accuracy: 0.9540 - val_loss: 0.2979
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.9720 - loss: 0.0684
# Epoch 6: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 43s 683ms/step - accuracy: 0.9720 - loss: 0.0684 - val_accuracy: 0.9470 - val_loss: 0.2170
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.9735 - loss: 0.0584
# Epoch 7: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 674ms/step - accuracy: 0.9736 - loss: 0.0583 - val_accuracy: 0.9430 - val_loss: 0.2255
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.9806 - loss: 0.0443
# Epoch 8: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 42s 677ms/step - accuracy: 0.9806 - loss: 0.0441 - val_accuracy: 0.9510 - val_loss: 0.2264
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.9879 - loss: 0.0283
# Epoch 9: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 45s 718ms/step - accuracy: 0.9879 - loss: 0.0283 - val_accuracy: 0.9570 - val_loss: 0.2254
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9881 - loss: 0.0208
# Epoch 10: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 44s 694ms/step - accuracy: 0.9881 - loss: 0.0208 - val_accuracy: 0.9590 - val_loss: 0.2334
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.9918 - loss: 0.0268
# Epoch 11: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 729ms/step - accuracy: 0.9917 - loss: 0.0268 - val_accuracy: 0.9500 - val_loss: 0.2612
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9883 - loss: 0.0256
# Epoch 12: val_loss did not improve from 0.20947
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 45s 723ms/step - accuracy: 0.9883 - loss: 0.0256 - val_accuracy: 0.9520 - val_loss: 0.2321

# %%
model.evaluate(test_dataset)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 23s 356ms/step - accuracy: 0.9216 - loss: 0.2092
# [0.20696935057640076, 0.9254999756813049]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Parameters
image_size = 180
input_shape = (image_size, image_size, 3)
epochs = 30
batch_size = 16

# Data augmentation for the training set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest'
)

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    new_base_dir / "train", 
    target_size = (180, 180),
    batch_size = 64,
    class_mode = 'binary')

validation_generator = test_datagen.flow_from_directory(
        new_base_dir / "validation",
        target_size=(180, 180),
        batch_size=32,
        class_mode='binary')

train_generator = train_datagen.flow_from_directory(
    new_base_dir / "train", 
    target_size = (180, 180),
    batch_size = 64,
    class_mode = 'binary')

test_generator = test_datagen.flow_from_directory(
        new_base_dir / "test",
        target_size=(180, 180),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
pip install scipy

# %%
# Load the pre-trained VGG16 model
pre_trained_model = VGG16(input_shape=input_shape, include_top=False, weights="imagenet")

# Freeze the initial layers to retain the learned features
for layer in pre_trained_model.layers[:15]:
    layer.trainable = False

# Unfreeze the remaining layers for fine-tuning
for layer in pre_trained_model.layers[15:]:
    layer.trainable = True

# Add custom layers on top of the pre-trained model
last_layer = pre_trained_model.get_layer('block5_pool')
last_output = last_layer.output

# Flatten the output layer to 1 dimension
x = GlobalMaxPooling2D()(last_output)
# Add a fully connected layer with 1024 hidden units and ReLU activation
x = Dense(512, activation='relu')(x)
# Add a dropout rate of 0.4
x = Dropout(0.4)(x)
# Add another fully connected layer with 512 hidden units and ReLU activation
x = Dense(256, activation='relu')(x)
# Add a dropout rate of 0.4
x = Dropout(0.4)(x)
# Add a final sigmoid layer for classification
x = Dense(1, activation='sigmoid')(x)

# Define the final model
model = Model(pre_trained_model.input, x)

# Compile the model with Adam optimizer
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(learning_rate=1e-4),
              metrics=['accuracy'])

# Define callbacks
checkpoint = ModelCheckpoint('best_model.keras',
                             monitor='val_loss',
                             save_best_only=True,
                             mode='min',
                             verbose=1)

early_stopping = EarlyStopping(patience=10, restore_best_weights=True)

lr_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                 patience=3, 
                                 verbose=1, 
                                 factor=0.5, 
                                 min_lr=0.00001)

# Train the model
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    callbacks=[checkpoint, early_stopping, lr_reduction]
)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6233 - loss: 0.6672
# Epoch 1: val_loss improved from inf to 0.21451, saving model to best_model.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.6260 - loss: 0.6633 - val_accuracy: 0.9060 - val_loss: 0.2145 - learning_rate: 1.0000e-04
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8707 - loss: 0.3017
# Epoch 2: val_loss did not improve from 0.21451
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.8707 - loss: 0.3017 - val_accuracy: 0.8980 - val_loss: 0.2184 - learning_rate: 1.0000e-04
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8933 - loss: 0.2343
# Epoch 3: val_loss improved from 0.21451 to 0.13863, saving model to best_model.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.8935 - loss: 0.2342 - val_accuracy: 0.9390 - val_loss: 0.1386 - learning_rate: 1.0000e-04
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9163 - loss: 0.1977
# Epoch 4: val_loss did not improve from 0.13863
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9164 - loss: 0.1977 - val_accuracy: 0.9350 - val_loss: 0.1572 - learning_rate: 1.0000e-04
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9380 - loss: 0.1635
# Epoch 5: val_loss improved from 0.13863 to 0.12813, saving model to best_model.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9378 - loss: 0.1640 - val_accuracy: 0.9480 - val_loss: 0.1281 - learning_rate: 1.0000e-04
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9337 - loss: 0.1618
# Epoch 6: val_loss did not improve from 0.12813
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9336 - loss: 0.1618 - val_accuracy: 0.9200 - val_loss: 0.1617 - learning_rate: 1.0000e-04
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9280 - loss: 0.1607
# Epoch 7: val_loss did not improve from 0.12813
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9281 - loss: 0.1609 - val_accuracy: 0.9360 - val_loss: 0.1374 - learning_rate: 1.0000e-04
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9529 - loss: 0.1165
# Epoch 8: val_loss improved from 0.12813 to 0.11202, saving model to best_model.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9527 - loss: 0.1171 - val_accuracy: 0.9510 - val_loss: 0.1120 - learning_rate: 1.0000e-04
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9560 - loss: 0.1198
# Epoch 9: val_loss did not improve from 0.11202
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9562 - loss: 0.1193 - val_accuracy: 0.9460 - val_loss: 0.1450 - learning_rate: 1.0000e-04
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9591 - loss: 0.1155
# Epoch 10: val_loss did not improve from 0.11202
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9588 - loss: 0.1159 - val_accuracy: 0.9470 - val_loss: 0.1211 - learning_rate: 1.0000e-04
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9611 - loss: 0.1091
# Epoch 11: val_loss did not improve from 0.11202
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9610 - loss: 0.1094 - val_accuracy: 0.9430 - val_loss: 0.1282 - learning_rate: 1.0000e-04
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9677 - loss: 0.0887
# Epoch 12: val_loss did not improve from 0.11202
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9678 - loss: 0.0884 - val_accuracy: 0.9520 - val_loss: 0.1158 - learning_rate: 5.0000e-05
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9721 - loss: 0.0738
# Epoch 13: val_loss did not improve from 0.11202
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9721 - loss: 0.0735 - val_accuracy: 0.9430 - val_loss: 0.1494 - learning_rate: 5.0000e-05
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9795 - loss: 0.0619
# Epoch 14: val_loss did not improve from 0.11202
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9795 - loss: 0.0618 - val_accuracy: 0.9550 - val_loss: 0.1286 - learning_rate: 5.0000e-05
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9845 - loss: 0.0382
# Epoch 15: val_loss did not improve from 0.11202
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.9844 - loss: 0.0384 - val_accuracy: 0.9530 - val_loss: 0.1283 - learning_rate: 2.5000e-05
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9765 - loss: 0.0629
# Epoch 16: val_loss did not improve from 0.11202
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9763 - loss: 0.0632 - val_accuracy: 0.9510 - val_loss: 0.1233 - learning_rate: 2.5000e-05
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9815 - loss: 0.0514
# Epoch 17: val_loss did not improve from 0.11202
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9814 - loss: 0.0515 - val_accuracy: 0.9510 - val_loss: 0.1332 - learning_rate: 2.5000e-05
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9713 - loss: 0.0597
# Epoch 18: val_loss did not improve from 0.11202
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.9716 - loss: 0.0593 - val_accuracy: 0.9480 - val_loss: 0.1176 - learning_rate: 1.2500e-05
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 546ms/step - accuracy: 0.9458 - loss: 0.1246
# Test accuracy: 0.9470000267028809

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna) (24.0)
# Collecting sqlalchemy>=1.3.0 (from optuna)
#   Downloading SQLAlchemy-2.0.31-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting tqdm (from optuna)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 5.9 MB/s eta 0:00:00a 0:00:01
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 14.3 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.31-cp39-cp39-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.8 MB/s eta 0:00:00ta 0:00:01
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 2.7 MB/s eta 0:00:00
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: tqdm, sqlalchemy, Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 optuna-3.6.1 sqlalchemy-2.0.31 tqdm-4.66.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install optuna-integration
# Out:
# Collecting optuna-integration
#   Downloading optuna_integration-3.6.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: optuna in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna-integration) (3.6.1)
# Requirement already satisfied: alembic>=1.5.0 in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna->optuna-integration) (1.13.2)
# Requirement already satisfied: colorlog in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna->optuna-integration) (6.8.2)
# Requirement already satisfied: numpy in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna->optuna-integration) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna->optuna-integration) (24.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna->optuna-integration) (2.0.31)
# Requirement already satisfied: tqdm in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna->optuna-integration) (4.66.4)
# Requirement already satisfied: PyYAML in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from optuna->optuna-integration) (6.0.1)
# Requirement already satisfied: Mako in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from alembic>=1.5.0->optuna->optuna-integration) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from alembic>=1.5.0->optuna->optuna-integration) (4.12.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/yasserali/anaconda3/envs/tf_m1/lib/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna->optuna-integration) (2.1.3)
# Downloading optuna_integration-3.6.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 kB 2.0 MB/s eta 0:00:0000:01
# Installing collected packages: optuna-integration
# Successfully installed optuna-integration-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import optuna
from optuna.integration import TFKerasPruningCallback
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, GlobalMaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras import optimizers

# Define the objective function for Optuna
def objective(trial):
    # Hyperparameters to tune
    dropout_rate = trial.suggest_float('dropout_rate', 0.2, 0.5)
    dense_units1 = trial.suggest_int('dense_units1', 256, 1024, step=128)
    dense_units2 = trial.suggest_int('dense_units2', 128, 512, step=64)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True)

    # Load the pre-trained VGG16 model
    pre_trained_model = VGG16(input_shape=input_shape, include_top=False, weights="imagenet")

    # Freeze the initial layers to retain the learned features
    for layer in pre_trained_model.layers[:15]:
        layer.trainable = False

    # Unfreeze the remaining layers for fine-tuning
    for layer in pre_trained_model.layers[15:]:
        layer.trainable = True

    # Add custom layers on top of the pre-trained model
    last_layer = pre_trained_model.get_layer('block5_pool')
    last_output = last_layer.output

    # Flatten the output layer to 1 dimension
    x = GlobalMaxPooling2D()(last_output)
    # Add a fully connected layer with dynamic units and ReLU activation
    x = Dense(dense_units1, activation='relu')(x)
    # Add a dropout layer
    x = Dropout(dropout_rate)(x)
    # Add another fully connected layer with dynamic units and ReLU activation
    x = Dense(dense_units2, activation='relu')(x)
    # Add another dropout layer
    x = Dropout(dropout_rate)(x)
    # Add a final sigmoid layer for classification
    x = Dense(1, activation='sigmoid')(x)

    # Define the final model
    model = Model(pre_trained_model.input, x)

    # Compile the model with dynamic learning rate
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizers.Adam(learning_rate=learning_rate),
                  metrics=['accuracy'])

    # Callbacks
    checkpoint = ModelCheckpoint('best_model.keras',
                                 monitor='val_loss',
                                 save_best_only=True,
                                 mode='min',
                                 verbose=1)

    early_stopping = EarlyStopping(patience=5, restore_best_weights=True)

    lr_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                     patience=3, 
                                     verbose=1, 
                                     factor=0.5, 
                                     min_lr=0.00001)

    # Train the model
    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=16,
        callbacks=[checkpoint, early_stopping, lr_reduction, TFKerasPruningCallback(trial, 'val_loss')],
        verbose=0  # Optuna handles verbosity
    )

    # Evaluate the model
    score = model.evaluate(validation_generator, verbose=0)
    return score[1]  # Return validation accuracy

# Create a study and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=5)

# Print the best trial
print(f'Best trial: {study.best_trial.params}')
# Out:
# [I 2024-07-24 16:04:32,245] A new study created in memory with name: no-name-347f09c0-1945-4014-a795-c736c38033f2
# Epoch 1: val_loss improved from inf to 0.39048, saving model to best_model.keras
#
# Epoch 2: val_loss improved from 0.39048 to 0.25649, saving model to best_model.keras
#
# Epoch 3: val_loss improved from 0.25649 to 0.22107, saving model to best_model.keras
#
# Epoch 4: val_loss improved from 0.22107 to 0.18468, saving model to best_model.keras
#
# Epoch 5: val_loss improved from 0.18468 to 0.17123, saving model to best_model.keras
#
# Epoch 6: val_loss did not improve from 0.17123
#
# Epoch 7: val_loss did not improve from 0.17123
#
# Epoch 8: val_loss improved from 0.17123 to 0.13507, saving model to best_model.keras
#
# Epoch 9: val_loss improved from 0.13507 to 0.12541, saving model to best_model.keras
#
# Epoch 10: val_loss did not improve from 0.12541
#
# Epoch 11: val_loss did not improve from 0.12541
#
# Epoch 12: val_loss did not improve from 0.12541
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00039062590803951025.
#
# Epoch 13: val_loss did not improve from 0.12541
#
# Epoch 14: val_loss improved from 0.12541 to 0.11300, saving model to best_model.keras
#
# Epoch 15: val_loss did not improve from 0.11300
#
# Epoch 16: val_loss did not improve from 0.11300
# [I 2024-07-24 16:18:13,710] Trial 0 finished with value: 0.9539999961853027 and parameters: {'dropout_rate': 0.21931647872115687, 'dense_units1': 256, 'dense_units2': 384, 'learning_rate': 0.000781251800550767}. Best is trial 0 with value: 0.9539999961853027.
# Epoch 1: val_loss improved from inf to 0.26399, saving model to best_model.keras
#
# Epoch 2: val_loss improved from 0.26399 to 0.22303, saving model to best_model.keras
#
# Epoch 3: val_loss improved from 0.22303 to 0.20443, saving model to best_model.keras
#
# Epoch 4: val_loss improved from 0.20443 to 0.19403, saving model to best_model.keras
#
# Epoch 5: val_loss improved from 0.19403 to 0.12365, saving model to best_model.keras
#
# Epoch 6: val_loss did not improve from 0.12365
#
# Epoch 7: val_loss did not improve from 0.12365
#
# Epoch 8: val_loss did not improve from 0.12365
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00023641844745725393.
#
# Epoch 9: val_loss improved from 0.12365 to 0.11538, saving model to best_model.keras
#
# Epoch 10: val_loss did not improve from 0.11538
#
# Epoch 11: val_loss did not improve from 0.11538
#
# Epoch 12: val_loss improved from 0.11538 to 0.09789, saving model to best_model.keras
#
# Epoch 13: val_loss did not improve from 0.09789
#
# Epoch 14: val_loss did not improve from 0.09789
#
# Epoch 15: val_loss did not improve from 0.09789
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00011820922372862697.
#
# Epoch 16: val_loss did not improve from 0.09789
# [I 2024-07-24 16:34:37,617] Trial 1 finished with value: 0.9599999785423279 and parameters: {'dropout_rate': 0.41372546309766084, 'dense_units1': 256, 'dense_units2': 448, 'learning_rate': 0.0004728369045576009}. Best is trial 1 with value: 0.9599999785423279.
# Epoch 1: val_loss improved from inf to 0.25440, saving model to best_model.keras
#
# Epoch 2: val_loss improved from 0.25440 to 0.19304, saving model to best_model.keras
#
# Epoch 3: val_loss improved from 0.19304 to 0.14705, saving model to best_model.keras
#
# Epoch 4: val_loss improved from 0.14705 to 0.14124, saving model to best_model.keras
#
# Epoch 5: val_loss improved from 0.14124 to 0.12532, saving model to best_model.keras
#
# Epoch 6: val_loss did not improve from 0.12532
#
# Epoch 7: val_loss did not improve from 0.12532
#
# Epoch 8: val_loss improved from 0.12532 to 0.11471, saving model to best_model.keras
#
# Epoch 9: val_loss did not improve from 0.11471
#
# Epoch 10: val_loss did not improve from 0.11471
#
# Epoch 11: val_loss improved from 0.11471 to 0.11187, saving model to best_model.keras
#
# Epoch 12: val_loss improved from 0.11187 to 0.10563, saving model to best_model.keras
#
# Epoch 13: val_loss did not improve from 0.10563
#
# Epoch 14: val_loss did not improve from 0.10563
#
# Epoch 15: val_loss did not improve from 0.10563
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.2807081879582256e-05.
#
# Epoch 16: val_loss did not improve from 0.10563
# [I 2024-07-24 16:50:49,586] Trial 2 finished with value: 0.953000009059906 and parameters: {'dropout_rate': 0.3335914626441595, 'dense_units1': 768, 'dense_units2': 256, 'learning_rate': 6.561416262227758e-05}. Best is trial 1 with value: 0.9599999785423279.
# Epoch 1: val_loss improved from inf to 0.58257, saving model to best_model.keras
#
# Epoch 2: val_loss improved from 0.58257 to 0.34828, saving model to best_model.keras
#
# Epoch 3: val_loss improved from 0.34828 to 0.28888, saving model to best_model.keras
#
# Epoch 4: val_loss improved from 0.28888 to 0.21997, saving model to best_model.keras
#
# Epoch 5: val_loss improved from 0.21997 to 0.21597, saving model to best_model.keras
#
# Epoch 6: val_loss did not improve from 0.21597
#
# Epoch 7: val_loss did not improve from 0.21597
#
# Epoch 8: val_loss did not improve from 0.21597
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0001532243040855974.
#
# Epoch 9: val_loss improved from 0.21597 to 0.18240, saving model to best_model.keras
#
# Epoch 10: val_loss improved from 0.18240 to 0.17558, saving model to best_model.keras
#
# Epoch 11: val_loss did not improve from 0.17558
#
# Epoch 12: val_loss did not improve from 0.17558
#
# Epoch 13: val_loss did not improve from 0.17558
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 7.66121520427987e-05.
#
# Epoch 14: val_loss improved from 0.17558 to 0.16961, saving model to best_model.keras
#
# Epoch 15: val_loss did not improve from 0.16961
#
# Epoch 16: val_loss did not improve from 0.16961
# [I 2024-07-24 17:06:26,681] Trial 3 finished with value: 0.9409999847412109 and parameters: {'dropout_rate': 0.2881604342392743, 'dense_units1': 768, 'dense_units2': 512, 'learning_rate': 0.0003064486008019583}. Best is trial 1 with value: 0.9599999785423279.
# Epoch 1: val_loss improved from inf to 0.17069, saving model to best_model.keras
#
# Epoch 2: val_loss improved from 0.17069 to 0.13432, saving model to best_model.keras
#
# Epoch 3: val_loss did not improve from 0.13432
#
# Epoch 4: val_loss did not improve from 0.13432
#
# Epoch 5: val_loss improved from 0.13432 to 0.12067, saving model to best_model.keras
#
# Epoch 6: val_loss did not improve from 0.12067
#
# Epoch 7: val_loss did not improve from 0.12067
#
# Epoch 8: val_loss did not improve from 0.12067
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 8.257825538748875e-05.
#
# Epoch 9: val_loss did not improve from 0.12067
#
# Epoch 10: val_loss improved from 0.12067 to 0.09070, saving model to best_model.keras
#
# Epoch 11: val_loss did not improve from 0.09070
#
# Epoch 12: val_loss did not improve from 0.09070
#
# Epoch 13: val_loss did not improve from 0.09070
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.1289127693744376e-05.
#
# Epoch 14: val_loss did not improve from 0.09070
#
# Epoch 15: val_loss did not improve from 0.09070
# [I 2024-07-24 17:23:16,180] Trial 4 finished with value: 0.9620000123977661 and parameters: {'dropout_rate': 0.22283358751648077, 'dense_units1': 1024, 'dense_units2': 384, 'learning_rate': 0.00016515650958538687}. Best is trial 4 with value: 0.9620000123977661.
# Best trial: {'dropout_rate': 0.22283358751648077, 'dense_units1': 1024, 'dense_units2': 384, 'learning_rate': 0.00016515650958538687}
